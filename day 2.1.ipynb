# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [1,2,3,4,5,6,7,8,9]
y = [10,20,30,40,50,60,70,80,90]
z = [10,20,30,40,50,60,70,80,90]
plt.plot(x,y,z)
plt.show()

# %%
x = [1,2,3,4,5,6,7,8,9]
y = [10,20,30,40,50,60,70,80,90]
z = [10,20,30,40,50,60,70,80,90]
plt.bar(x,y)
plt.show()

# %%
x = [1,2,3,4,5,6,7,8,9]


plt.hist(x)
plt.show()

# %%
x = [1,2,3,4,5,6,7,8,9]
y = [10,20,30,40,50,60,70,80,90]

plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.plot(x,y)
plt.show()

# %%
name = ["a","b","c","d","e","f","g","h","i"]
y = [10,20,30,40,50,60,70,80,90]

plt.xlabel("name")
plt.ylabel("marks")
plt.bar(name,y)
plt.show()

# %%
labels = ["a","b","c","d","e","f","g","h","i","j"]
sizes = [1,54,86,96,74,12,52,45,23,43]
plt.pie(sizes, labels=labels, autopct='%1.1f%%',startangle=45,shadow=True)
plt.title("pie chart")
plt.show()
