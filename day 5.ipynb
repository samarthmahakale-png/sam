# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import numpy as np

df["promotion"] = (df["Performance_Rating"] >= 4).astype(int)
X = df[["Experience_Years", "Performance_Rating", "Overtime_Hours"]]
y = df["promotion"]

# Drop rows with any NaN or infinity values from X and corresponding y
cleaned_data = pd.concat([X, y], axis=1).replace([np.inf, -np.inf], np.nan).dropna()
X_cleaned = cleaned_data[X.columns]
y_cleaned = cleaned_data[y.name]

print("Value counts for 'promotion' (y):")
print(y_cleaned.value_counts())

print("Minimum Performance_Rating in df:", X_cleaned["Performance_Rating"].min())
print("Maximum Performance_Rating in df:", X_cleaned["Performance_Rating"].max())
X_train, X_test, y_train, y_test = train_test_split(
    X_cleaned, y_cleaned, test_size=0.2, random_state=42)
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Value counts for 'promotion' (y):
# promotion
# 1    30
# 0    10
# Name: count, dtype: int64
# Minimum Performance_Rating in df: 3.5
# Maximum Performance_Rating in df: 5.0
# Accuracy: 0.875
# Confusion Matrix:
# [[0 0]
#  [1 7]]

# %%
# Import Libraries
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Upload CSV file
uploaded = files.upload()

# Read Dataset
df = pd.read_csv("/content/Indian_Employee_Data.csv")

# Display first 5 rows
df.head()
# Out:
#      <input type="file" id="files-4330d69d-f3a3-4034-a4e0-621a46d746e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4330d69d-f3a3-4034-a4e0-621a46d746e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# Load Dataset
sana = pd.read_csv("Cleaned_Indian_Employee_Data.csv")

# Create Target Variable
sana["promotion"] = (sana["Performance_Rating"] >= 3).astype(int)

# Independent Variables
x = sana[["Experience_Years", "Performance_Rating", "Overtime_Hours"]]

# Dependent Variable
y = sana["promotion"]

# Display Information
print("Value counts for promotion (y):")
print(y.value_counts())

print("\nMinimum Performance_Rating:", sana["Performance_Rating"].min())
print("Maximum Performance_Rating:", sana["Performance_Rating"].max())

import numpy as np

x = x.replace([np.inf, -np.inf], np.nan)

x = x.fillna(x.mean())

# Train-Test Split
x_train, x_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.2,
    random_state=42
)

# Create Model
model = LogisticRegression(max_iter=1000)

# Train Model
model.fit(x_train, y_train)

# Prediction
y_pred = model.predict(x_test)

# Accuracy
print("\nAccuracy:", accuracy_score(y_test, y_pred))

# Confusion Matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Value counts for promotion (y):
# promotion
# 1    49
# Name: count, dtype: int64
#
# Minimum Performance_Rating: 3.5
# Maximum Performance_Rating: 5.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_753/3503626722.py in <cell line: 0>()
#      41
#      42 # Train Model
# ---> 43 model.fit(x_train, y_train)
#      44
#      45 # Prediction
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1299         classes_ = self.classes_
#    1300         if n_classes < 2:
# -> 1301             raise ValueError(
# ...

# %%
# Import Libraries
import pandas as pd
import numpy as np

# Load Dataset
df = pd.read_csv("Indian_Employee_Data.csv")

# Display first 5 rows
print(df.head())

# Check dataset information
print(df.info())

# Check missing values
print(df.isnull().sum())

# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Fill missing values
df["Salary"].fillna(df["Salary"].mean(), inplace=True)
df["Experience_Years"].fillna(df["Experience_Years"].median(), inplace=True)

# Fill missing categorical values
df["Department"].fillna(df["Department"].mode()[0], inplace=True)
df["City"].fillna(df["City"].mode()[0], inplace=True)

# Remove rows with remaining missing values
df.dropna(inplace=True)

# Convert data types
df["Salary"] = df["Salary"].astype(int)
df["Experience_Years"] = df["Experience_Years"].astype(int)

# Save cleaned dataset
df.to_csv("Cleaned_Indian_Employee_Data.csv", index=False)

print("Dataset cleaned successfully!")
# Out:
#   Employee_ID          Name  Age  Gender   Department           Position  \
# 0      EMP001  Rajesh Kumar   32    Male  Engineering   Senior Developer
# 1      EMP002  Priya Sharma   28  Female    Marketing  Marketing Manager
# 2      EMP003    Amit Singh   35    Male      Finance  Financial Analyst
# 3      EMP004   Sneha Patel   26  Female          NaN       HR Executive
# 4      EMP005  Vikram Reddy   40    Male  Engineering          Tech Lead
#
#       Salary  Experience_Years       City        State Education  \
# 0   850000.0               8.0  Bangalore    Karnataka    B.Tech
# 1   720000.0               5.0     Mumbai  Maharashtra       MBA
# 2   650000.0              10.0      Delhi        Delhi        CA
# 3   480000.0               3.0  Ahmedabad      Gujarat       MBA
# 4  1200000.0              15.0  Hyderabad    Telangana    M.Tech
#
#    Performance_Rating Joining_Date  Projects_Completed  Overtime_Hours
# ...
